# %%
import numpy as np

# %%
from keras.models import Sequential

# %%
import tensorflow as tf

# %%
from platform import python_version

# %%
print(python_version())
# Out:
# 3.10.5

# %%
from sentence_transformers import SentenceTransformer

# %%
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# {"timestamp":"2025-06-11T06:13:14.976070Z","level":"WARN","fields":{"message":"Reqwest(reqwest::Error { kind: Request, url: \"https://transfer.xethub.hf.co/xorbs/default/e34531551f0153d1d7a1d6f440aabdb524664fa6ea6b227cc6f350b492891e1c?X-Xet-Signed-Range=bytes%3D6489563-15285330&Expires=1749625950&Policy=__&Signature=Duoac8v~n8N9314wiH2ipizzF0Hp07aN3ah0PDDY8l5ustVWDK9mlxqQcwAcFMQkE9dFuwvsDL8e-KHR84m0bLbx3uC1T6bZWw1OhwEhsVJRAw6FHK8YrIWdZFgfQJ8AwAf6XCM37hBmWYI2WJsdT3Vr6qQ9dHw~cHzcM1T2bYqzI~hd-p9rG9BlB~RowLlmP36yUdsb0AhQ8Smk0Z1kYSQ9TdAhWz3j8addgR1OSjpbYHfePcPxGCM8N~IIw580uxGNucjZgd8s4uyLTEW5M500R59-z685OiLkhSoueZcI3iI8QsNHzz~1jgI8jK2lqcJUfvffL6p3SccS5~fksA__&Key-Pair-Id=K2L8F4GPSG1IFC\", source: hyper_util::client::legacy::Error(SendRequest, hyper::Error(IncompleteMessage)) }). Retrying..."},"filename":"/Users/runner/work/xet-core/xet-core/cas_client/src/http_client.rs","line_number":200}
# {"timestamp":"2025-06-11T06:13:14.976267Z","level":"WARN","fields":{"message":"Retry attempt #0. Sleeping 2.079292142s before the next attempt"},"filename":"/Users/runner/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/reqwest-retry-0.7.0/src/middleware.rs","line_number":171}
# {"timestamp":"2025-06-11T06:13:52.239057Z","level":"ERROR","fields":{"message":"error downloading range, error: ReqwestMiddlewareError(Middleware(error sending request for url (https://transfer.xethub.hf.co/xorbs/default/f7e7236542787ccde51b6c13296410e6605d532a1436fb8aa1d843bf27dc3260?X-Xet-Signed-Range=bytes%3D25453312-27343116&Expires=1749625950&Policy=_&Signature=YMU7vj1K6Ozbg--hkICaUz-emwlkSLL98gfoXHOVi8eFUlsoXZY0ZL59nVr4jw04oFzDN~vr62clfUjElVp5S2Yuv666y56ohzvRJupV5I9wi0~RWGpWp9nqEMaVfxH8snt~~GOKvB7joJBdoHHvXraWqJyOS~qngmpTQ1UuILzNtQ1nVIENTT1DHVJxDhsuG9-ud9IpolXBGDTjMC177IO~oYrR08w6GTiFDppO4A8WzyjbX7md8x5CqUSakpzGGivAjmKQKRuBrdXx9qo-bx6L13qZ8qy~dnC8LhMEwjAezXtvxyLX2gJzXVdzT~Fm~wxwXYLoswYKGcx7CaBbKg__&Key-Pair-Id=K2L8F4GPSG1IFC)\n\nCaused by:\n    0: client error (SendRequest)\n    1: channel closed))","caller":"/Users/runner/work/xet-core/xet-core/cas_client/src/download_utils.rs:528"},"filename":"/Users/runner/work/xet-core/xet-core/error_printer/src/lib.rs","line_number":28}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/modeling_utils.py:1024, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, transformers_explicit_filename)
#    1011 cached_file_kwargs = {
#    1012     "cache_dir": cache_dir,
#    1013     "force_download": force_download,
#    (...)
#    1022     "_commit_hash": commit_hash,
#    1023 }
# -> 1024 resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    1026 # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    1027 # result when internet is up, the repo and revision exist, but the file does not.
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/utils/hub.py:312, in cached_file(path_or_repo_id, filename, **kwargs)
#     259 """
#     260 Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     261
#    (...)
#     310 ```
#     311 """
# --> 312 file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     313 file = file[0] if file is not None else file
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/utils/hub.py:557, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     556     elif not isinstance(e, EntryNotFoundError):
# --> 557         raise e
#     559 resolved_files = [
#     560     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     561 ]
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/utils/hub.py:470, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     468 if len(full_filenames) == 1:
#     469     # This is slightly better for only 1 file
# --> 470     hf_hub_download(
#     471         path_or_repo_id,
#     472         filenames[0],
#     473         subfolder=None if len(subfolder) == 0 else subfolder,
#     474         repo_type=repo_type,
#     475         revision=revision,
#     476         cache_dir=cache_dir,
#     477         user_agent=user_agent,
#     478         force_download=force_download,
#     479         proxies=proxies,
#     480         resume_download=resume_download,
#     481         token=token,
#     482         local_files_only=local_files_only,
#     483     )
#     484 else:
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/huggingface_hub/file_download.py:1008, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1007 else:
# -> 1008     return _hf_hub_download_to_cache_dir(
#    1009         # Destination
#    1010         cache_dir=cache_dir,
#    1011         # File info
#    1012         repo_id=repo_id,
#    1013         filename=filename,
#    1014         repo_type=repo_type,
#    1015         revision=revision,
#    1016         # HTTP info
#    1017         endpoint=endpoint,
#    1018         etag_timeout=etag_timeout,
#    1019         headers=hf_headers,
#    1020         proxies=proxies,
#    1021         token=token,
#    1022         # Additional options
#    1023         local_files_only=local_files_only,
#    1024         force_download=force_download,
#    1025     )
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/huggingface_hub/file_download.py:1161, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1160 with WeakFileLock(lock_path):
# -> 1161     _download_to_tmp_and_move(
#    1162         incomplete_path=Path(blob_path + ".incomplete"),
#    1163         destination_path=Path(blob_path),
#    1164         url_to_download=url_to_download,
#    1165         proxies=proxies,
#    1166         headers=headers,
#    1167         expected_size=expected_size,
#    1168         filename=filename,
#    1169         force_download=force_download,
#    1170         etag=etag,
#    1171         xet_file_data=xet_file_data,
#    1172     )
#    1173     if not os.path.exists(pointer_path):
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/huggingface_hub/file_download.py:1710, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1709     logger.info("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1710     xet_get(
#    1711         incomplete_path=incomplete_path,
#    1712         xet_file_data=xet_file_data,
#    1713         headers=headers,
#    1714         expected_size=expected_size,
#    1715         displayed_filename=filename,
#    1716     )
#    1717 else:
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/huggingface_hub/file_download.py:627, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     625     progress.update(progress_bytes)
# --> 627 download_files(
#     628     xet_download_info,
#     629     endpoint=connection_info.endpoint,
#     630     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     631     token_refresher=token_refresher,
#     632     progress_updater=[progress_updater],
#     633 )
#
# RuntimeError: Data processing error: CAS service error : Error : single flight error: Real call failed: ReqwestMiddlewareError(Middleware(error sending request for url (https://transfer.xethub.hf.co/xorbs/default/f7e7236542787ccde51b6c13296410e6605d532a1436fb8aa1d843bf27dc3260?X-Xet-Signed-Range=bytes%3D25453312-27343116&Expires=1749625950&Policy=_&Signature=YMU7vj1K6Ozbg--hkICaUz-emwlkSLL98gfoXHOVi8eFUlsoXZY0ZL59nVr4jw04oFzDN~vr62clfUjElVp5S2Yuv666y56ohzvRJupV5I9wi0~RWGpWp9nqEMaVfxH8snt~~GOKvB7joJBdoHHvXraWqJyOS~qngmpTQ1UuILzNtQ1nVIENTT1DHVJxDhsuG9-ud9IpolXBGDTjMC177IO~oYrR08w6GTiFDppO4A8WzyjbX7md8x5CqUSakpzGGivAjmKQKRuBrdXx9qo-bx6L13qZ8qy~dnC8LhMEwjAezXtvxyLX2gJzXVdzT~Fm~wxwXYLoswYKGcx7CaBbKg__&Key-Pair-Id=K2L8F4GPSG1IFC)
#
# Caused by:
#     0: client error (SendRequest)
#     1: channel closed))
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:309, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     300         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     302 if is_sentence_transformer_model(
#     303     model_name_or_path,
#     304     token,
#    (...)
#     307     local_files_only=local_files_only,
#     308 ):
# --> 309     modules, self.module_kwargs = self._load_sbert_model(
#     310         model_name_or_path,
#     311         token=token,
#     312         cache_folder=cache_folder,
#     313         revision=revision,
#     314         trust_remote_code=trust_remote_code,
#     315         local_files_only=local_files_only,
#     316         model_kwargs=model_kwargs,
#     317         tokenizer_kwargs=tokenizer_kwargs,
#     318         config_kwargs=config_kwargs,
#     319     )
#     320 else:
#     321     modules = self._load_auto_model(
#     322         model_name_or_path,
#     323         token=token,
#    (...)
#     330         config_kwargs=config_kwargs,
#     331     )
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:1808, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    1805 # Try to initialize the module with a lot of kwargs, but only if the module supports them
#    1806 # Otherwise we fall back to the load method
#    1807 try:
# -> 1808     module = module_class(model_name_or_path, cache_dir=cache_folder, backend=self.backend, **kwargs)
#    1809 except TypeError:
#    1810     module = module_class.load(model_name_or_path)
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:81, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      78     config_args = {}
#      80 config, is_peft_model = self._load_config(model_name_or_path, cache_dir, backend, config_args)
# ---> 81 self._load_model(model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#      83 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#      84     tokenizer_args["model_max_length"] = max_seq_length
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:181, in Transformer._load_model(self, model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#     179     self._load_mt5_model(model_name_or_path, config, cache_dir, **model_args)
#     180 else:
# --> 181     self.auto_model = AutoModel.from_pretrained(
#     182         model_name_or_path, config=config, cache_dir=cache_dir, **model_args
#     183     )
#     185 if is_peft_model:
#     186     self._load_peft_model(model_name_or_path, config, cache_dir, **model_args, **adapter_only_kwargs)
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:571, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569     if model_class.config_class == config.sub_configs.get("text_config", None):
#     570         config = config.get_text_config()
# --> 571     return model_class.from_pretrained(
#     572         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573     )
#     574 raise ValueError(
#     575     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     576     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     577 )
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/modeling_utils.py:309, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     307 old_dtype = torch.get_default_dtype()
#     308 try:
# --> 309     return func(*args, **kwargs)
#     310 finally:
#     311     torch.set_default_dtype(old_dtype)
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/modeling_utils.py:4422, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4412 if (
#    4413     gguf_file
#    4414     and device_map is not None
#    4415     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4416 ):
#    4417     raise RuntimeError(
#    4418         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4419         "loaded from GGUF files."
#    4420     )
# -> 4422 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4423     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4424     subfolder=subfolder,
#    4425     variant=variant,
#    4426     gguf_file=gguf_file,
#    4427     from_tf=from_tf,
#    4428     from_flax=from_flax,
#    4429     use_safetensors=use_safetensors,
#    4430     cache_dir=cache_dir,
#    4431     force_download=force_download,
#    4432     proxies=proxies,
#    4433     local_files_only=local_files_only,
#    4434     token=token,
#    4435     user_agent=user_agent,
#    4436     revision=revision,
#    4437     commit_hash=commit_hash,
#    4438     transformers_explicit_filename=transformers_explicit_filename,
#    4439 )
#    4441 is_sharded = sharded_metadata is not None
#    4442 is_quantized = hf_quantizer is not None
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/transformers/modeling_utils.py:1139, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, transformers_explicit_filename)
#    1136         raise
#    1137     except Exception as e:
#    1138         # For any other exception, we throw a generic error.
# -> 1139         raise EnvironmentError(
#    1140             f"Can't load the model for '{pretrained_model_name_or_path}'. If you were trying to load it"
#    1141             " from 'https://huggingface.co/models', make sure you don't have a local directory with the"
#    1142             f" same name. Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a"
#    1143             f" directory containing a file named {_add_variant(WEIGHTS_NAME, variant)},"
#    1144             f" {TF2_WEIGHTS_NAME}, {TF_WEIGHTS_NAME} or {FLAX_WEIGHTS_NAME}."
#    1145         ) from e
#    1147 if is_local:
#    1148     logger.info(f"loading weights file {archive_file}")
#
# OSError: Can't load the model for 'sentence-transformers/bert-base-nli-mean-tokens'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'sentence-transformers/bert-base-nli-mean-tokens' is the correct path to a directory containing a file named pytorch_model.bin, tf_model.h5, model.ckpt or flax_model.msgpack.
# {"timestamp":"2025-06-11T06:14:11.529740Z","level":"ERROR","fields":{"message":"error downloading range, error: ReqwestMiddlewareError(Middleware(Request failed after 1 retries\n\nCaused by:\n    0: error sending request for url (https://transfer.xethub.hf.co/xorbs/default/e34531551f0153d1d7a1d6f440aabdb524664fa6ea6b227cc6f350b492891e1c?X-Xet-Signed-Range=bytes%3D6489563-15285330&Expires=1749625950&Policy=__&Signature=Duoac8v~n8N9314wiH2ipizzF0Hp07aN3ah0PDDY8l5ustVWDK9mlxqQcwAcFMQkE9dFuwvsDL8e-KHR84m0bLbx3uC1T6bZWw1OhwEhsVJRAw6FHK8YrIWdZFgfQJ8AwAf6XCM37hBmWYI2WJsdT3Vr6qQ9dHw~cHzcM1T2bYqzI~hd-p9rG9BlB~RowLlmP36yUdsb0AhQ8Smk0Z1kYSQ9TdAhWz3j8addgR1OSjpbYHfePcPxGCM8N~IIw580uxGNucjZgd8s4uyLTEW5M500R59-z685OiLkhSoueZcI3iI8QsNHzz~1jgI8jK2lqcJUfvffL6p3SccS5~fksA__&Key-Pair-Id=K2L8F4GPSG1IFC)\n    1: client error (SendRequest)\n    2: channel closed))","caller":"/Users/runner/work/xet-core/xet-core/cas_client/src/download_utils.rs:528"},"filename":"/Users/runner/work/xet-core/xet-core/error_printer/src/lib.rs","line_number":28}
# {"timestamp":"2025-06-11T06:14:50.531143Z","level":"WARN","fields":{"message":"Reqwest(reqwest::Error { kind: Request, url: \"https://transfer.xethub.hf.co/xorbs/default/1a0044bc06a058373c8f27c5dc842491dc1a2b406a1bf3c73e7e7990421fc6ac?X-Xet-Signed-Range=bytes%3D58028813-63631544&Expires=1749625950&Policy=_&Signature=V38S7YsnS9zG0jZETNggWa06Hai2r7affbFouzC33uuTXWp0gdgdCwET0rBYSXtqg1LZ~zyM12swUdnEYC73L0sInu7Z7DoL6QWtpNKlRe1j~td4yBbYe-WP92Tayig5qvX~R~TrlMT21zTK-IQKkqyy6w7crGhHRGZBwxjfGhIGtaHKPkptno2PVNQ4pOCjOMCKxzUtQmignq~4f3p3Mpi9BB1UNvcKS6TgfzNLALi2k7UTJL~ZG~xfqIuUl8ZaHr0A88O1n1aXz0Xcizc~VGFXsnXPSHczwra9JQohkTo7QLdfVeMK5yCLWA9Z1ZlJjSlGWQBPmiTn55pd0xaWnA__&Key-Pair-Id=K2L8F4GPSG1IFC\", source: hyper_util::client::legacy::Error(SendRequest, hyper::Error(IncompleteMessage)) }). Retrying..."},"filename":"/Users/runner/work/xet-core/xet-core/cas_client/src/http_client.rs","line_number":200}
# {"timestamp":"2025-06-11T06:14:50.531283Z","level":"WARN","fields":{"message":"Retry attempt #0. Sleeping 2.802625239s before the next attempt"},"filename":"/Users/runner/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/reqwest-retry-0.7.0/src/middleware.rs","line_number":171}
# {"timestamp":"2025-06-11T06:15:23.007249Z","level":"WARN","fields":{"message":"Reqwest(reqwest::Error { kind: Request, url: \"https://transfer.xethub.hf.co/xorbs/default/f7e7236542787ccde51b6c13296410e6605d532a1436fb8aa1d843bf27dc3260?X-Xet-Signed-Range=bytes%3D34158968-36289496&Expires=1749625950&Policy=_&Signature=ZDAoHSXHyaVrz7rIR1ZkDly42JoLz5Ix8XhGxJ2q6aiUUbGRV7LzULEzU1cq3Eh7ISCQb1ANbiBVuKQYxHFR1HvlnBSAFqEzMyqSKCcrK8B1GAxbVvonqOAeAkV6SnKCACE0HCcfZS0k1WgLz1PF9b3gWg7tc8sTwaYKvSRROpqLMMfDAAVcdSgVcPyoDhANiKGUN~c5bjbAor9ESEWB55FlaCT9XfV6D~4RlJ-yz3J6pyJdSbNPu62MrL9YC3RT51IM-84oWECzHTJM3~JkITRQbgJXeAKWa5mku0hulmKV~MSG0dIaw6iN1Kx-7HOWHqFZhBPgTrBEkJ8DtGXP5w__&Key-Pair-Id=K2L8F4GPSG1IFC\", source: hyper_util::client::legacy::Error(SendRequest, hyper::Error(IncompleteMessage)) }). Retrying..."},"filename":"/Users/runner/work/xet-core/xet-core/cas_client/src/http_client.rs","line_number":200}
# {"timestamp":"2025-06-11T06:15:23.007339Z","level":"WARN","fields":{"message":"Retry attempt #0. Sleeping 2.477875474s before the next attempt"},"filename":"/Users/runner/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/reqwest-retry-0.7.0/src/middleware.rs","line_number":171}

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from gensim.models.doc2vec import Doc2Vec, TaggedDocument
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/gensim/corpora/__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/gensim/corpora/indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/gensim/interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/gensim/matutils.py:1034
#    1029     return 1. - float(len(set1 & set2)) / float(union_cardinality)
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1036 except ImportError:
#    1037     def logsumexp(x):
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/gensim/_matutils.pyx:1, in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
