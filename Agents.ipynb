# %%
from agents import Agent, Runner

agent = Agent(name="Assistant", instructions="You are a helpful assistant")

result = Runner.run_sync(agent, "Write a haiku about recursion in programming.")
print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 5
#       1 from agents import Agent, Runner
#       3 agent = Agent(name="Assistant", instructions="You are a helpful assistant")
# ----> 5 result = Runner.run_sync(agent, "Write a haiku about recursion in programming.")
#       6 print(result.final_output)
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/agents/run.py:252, in Runner.run_sync(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id)
#     222 """Run a workflow synchronously, starting at the given agent. Note that this just wraps the
#     223 `run` method, so it will not work if there's already an event loop (e.g. inside an async
#     224 function, or in a Jupyter notebook or async context like FastAPI). For those cases, use
#    (...)
#     249     agent. Agents may perform handoffs, so we don't know the specific type of the output.
#     250 """
#     251 runner = DEFAULT_AGENT_RUNNER
# --> 252 return runner.run_sync(
#     253     starting_agent,
#     254     input,
#     255     context=context,
#     256     max_turns=max_turns,
#     257     hooks=hooks,
#     258     run_config=run_config,
#     259     previous_response_id=previous_response_id,
#     260 )
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/agents/run.py:491, in AgentRunner.run_sync(self, starting_agent, input, **kwargs)
#     489 run_config = kwargs.get("run_config")
#     490 previous_response_id = kwargs.get("previous_response_id")
# --> 491 return asyncio.get_event_loop().run_until_complete(
#     492     self.run(
#     493         starting_agent,
#     494         input,
#     495         context=context,
#     496         max_turns=max_turns,
#     497         hooks=hooks,
#     498         run_config=run_config,
#     499         previous_response_id=previous_response_id,
#     500     )
#     501 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py:622, in BaseEventLoop.run_until_complete(self, future)
#     611 """Run until the Future is done.
#     612
#     613 If the argument is a coroutine, it is wrapped in a Task.
#    (...)
#     619 Return the Future's result, or raise its exception.
#     620 """
#     621 self._check_closed()
# --> 622 self._check_running()
#     624 new_task = not futures.isfuture(future)
#     625 future = tasks.ensure_future(future, loop=self)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py:582, in BaseEventLoop._check_running(self)
#     580 def _check_running(self):
#     581     if self.is_running():
# --> 582         raise RuntimeError('This event loop is already running')
#     583     if events._get_running_loop() is not None:
#     584         raise RuntimeError(
#     585             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running

# %% [markdown]
# ## CrewAI based agent

# %%
from crewai import Agent, Task, Crew
from langchain_community.tools import DuckDuckGoSearchRun
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/utils/embedding_functions/onnx_mini_lm_l6_v2.py:63, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      61 try:
#      62     # Equivalent to import onnxruntime
# ---> 63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/onnxruntime/__init__.py:61
#      60 if import_capi_exception:
# ---> 61     raise import_capi_exception
#      63 from onnxruntime.capi.onnxruntime_inference_collection import (
#      64     AdapterFormat,  # noqa: F401
#      65     InferenceSession,  # noqa: F401
#    (...)
#      69     SparseTensor,  # noqa: F401
#      70 )
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/onnxruntime/__init__.py:24
#      23 try:
# ---> 24     from onnxruntime.capi._pybind_state import (
#      25         ExecutionMode,  # noqa: F401
#      26         ExecutionOrder,  # noqa: F401
#      27         GraphOptimizationLevel,  # noqa: F401
#      28         LoraAdapter,  # noqa: F401
#      29         ModelMetadata,  # noqa: F401
#      30         NodeArg,  # noqa: F401
#      31         OrtAllocatorType,  # noqa: F401
#      32         OrtArenaCfg,  # noqa: F401
#      33         OrtMemoryInfo,  # noqa: F401
#      34         OrtMemType,  # noqa: F401
#      35         OrtSparseFormat,  # noqa: F401
#      36         RunOptions,  # noqa: F401
#      37         SessionIOBinding,  # noqa: F401
#      38         SessionOptions,  # noqa: F401
#      39         create_and_register_allocator,  # noqa: F401
#      40         create_and_register_allocator_v2,  # noqa: F401
#      41         disable_telemetry_events,  # noqa: F401
#      42         enable_telemetry_events,  # noqa: F401
#      43         get_all_providers,  # noqa: F401
#      44         get_available_providers,  # noqa: F401
#      45         get_build_info,  # noqa: F401
#      46         get_device,  # noqa: F401
#      47         get_version_string,  # noqa: F401
#      48         has_collective_ops,  # noqa: F401
#      49         set_default_logger_severity,  # noqa: F401
#      50         set_default_logger_verbosity,  # noqa: F401
#      51         set_seed,  # noqa: F401
#      52     )
#      54     import_capi_exception = None
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/onnxruntime/capi/_pybind_state.py:32
#      25             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      26                           "If you've installed the runtime in a non-standard location "
#      27                           "(other than %SystemRoot%\\System32), "
#      28                           "make sure it can be found by setting the correct path.")
# ---> 32 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: dlopen(/Users/ankur/Projects/Codes/aidash/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_pybind11_state.so, 0x0002): Symbol not found: __ZNSt3__18to_charsEPcS0_d
#   Referenced from: <EC7F3DB3-CC4A-307A-AB61-7C7D182EE2E9> /Users/ankur/Projects/Codes/aidash/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_pybind11_state.so (built for macOS 13.3 which is newer than running OS)
#   Expected in:     <E2679357-B2AF-30D4-8130-50D31765AF88> /usr/lib/libc++.1.dylib
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from crewai import Agent, Task, Crew
#       2 from langchain_community.tools import DuckDuckGoSearchRun
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/crewai/__init__.py:5
#       2 import threading
#       3 import urllib.request
# ----> 5 from crewai.agent import Agent
#       6 from crewai.crew import Crew
#       7 from crewai.crews.crew_output import CrewOutput
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/crewai/agent.py:8
#       4 from typing import Any, Callable, Dict, List, Literal, Optional, Sequence, Tuple, Type, Union
#       6 from pydantic import Field, InstanceOf, PrivateAttr, model_validator
# ----> 8 from crewai.agents import CacheHandler
#       9 from crewai.agents.agent_builder.base_agent import BaseAgent
#      10 from crewai.agents.crew_agent_executor import CrewAgentExecutor
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/crewai/agents/__init__.py:2
#       1 from .cache.cache_handler import CacheHandler
# ----> 2 from .parser import CrewAgentParser
#       3 from .tools_handler import ToolsHandler
#       5 __all__ = ["CacheHandler", "CrewAgentParser", "ToolsHandler"]
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/crewai/agents/parser.py:6
#       2 from typing import Any, Optional, Union
#       4 from json_repair import repair_json
# ----> 6 from crewai.utilities import I18N
#       8 FINAL_ANSWER_ACTION = "Final Answer:"
#       9 MISSING_ACTION_AFTER_THOUGHT_ERROR_MESSAGE = "I did it wrong. Invalid Format: I missed the 'Action:' after 'Thought:'. I will do right next, and don't use a tool I have already used.\n"
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/crewai/utilities/__init__.py:13
#       9 from .rpm_controller import RPMController
#      10 from .exceptions.context_window_exceeding_exception import (
#      11     LLMContextLengthExceededException,
#      12 )
# ---> 13 from .embedding_configurator import EmbeddingConfigurator
#      15 __all__ = [
#      16     "Converter",
#      17     "ConverterError",
#    (...)
#      27     "EmbeddingConfigurator",
#      28 ]
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/crewai/utilities/embedding_configurator.py:4
#       1 import os
#       2 from typing import Any, Dict, Optional, cast
# ----> 4 from chromadb import Documents, EmbeddingFunction, Embeddings
#       5 from chromadb.api.types import validate_embedding_function
#       8 class EmbeddingConfigurator:
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.api.async_client import AsyncClient as AsyncClientCreator
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/api/__init__.py:34
#      32 from chromadb.types import Database, Tenant, Collection as CollectionModel
#      33 import chromadb.utils.embedding_functions as ef
# ---> 34 from chromadb.api.models.Collection import Collection
#      37 # Re-export the async version
#      38 from chromadb.api.async_api import (  # noqa: F401
#      39     AsyncBaseAPI as AsyncBaseAPI,
#      40     AsyncClientAPI as AsyncClientAPI,
#      41     AsyncAdminAPI as AsyncAdminAPI,
#      42     AsyncServerAPI as AsyncServerAPI,
#      43 )
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/api/models/Collection.py:3
#       1 from typing import TYPE_CHECKING, Optional, Union
# ----> 3 from chromadb.api.models.CollectionCommon import CollectionCommon
#       4 from chromadb.api.types import (
#       5     URI,
#       6     CollectionMetadata,
#    (...)
#      21     IncludeEnum,
#      22 )
#      24 import logging
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/api/models/CollectionCommon.py:100
#      95         return wrapper
#      97     return decorator
# --> 100 class CollectionCommon(Generic[ClientT]):
#     101     _model: CollectionModel
#     102     _client: ClientT
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/api/models/CollectionCommon.py:112, in CollectionCommon()
#     103 _embedding_function: Optional[EmbeddingFunction[Embeddable]]
#     104 _data_loader: Optional[DataLoader[Loadable]]
#     106 def __init__(
#     107     self,
#     108     client: ClientT,
#     109     model: CollectionModel,
#     110     embedding_function: Optional[
#     111         EmbeddingFunction[Embeddable]
# --> 112     ] = ef.DefaultEmbeddingFunction(),  # type: ignore
#     113     data_loader: Optional[DataLoader[Loadable]] = None,
#     114 ):
#     115     """Initializes a new instance of the Collection class."""
#     117     self._client = client
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/utils/embedding_functions/__init__.py:57, in DefaultEmbeddingFunction()
#      52     return None
#      53 else:
#      54     return cast(
#      55         EmbeddingFunction[Documents],
#      56         # This is implicitly imported above
# ---> 57         ONNXMiniLM_L6_V2(),  # type: ignore[name-defined] # noqa: F821
#      58     )
#
# File ~/Projects/Codes/aidash/lib/python3.10/site-packages/chromadb/utils/embedding_functions/onnx_mini_lm_l6_v2.py:65, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
# ---> 65     raise ValueError(
#      66         "The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`"
#      67     )
#      68 try:
#      69     # Equivalent to from tokenizers import Tokenizer
#      70     self.Tokenizer = importlib.import_module("tokenizers").Tokenizer
#
# ValueError: The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`
